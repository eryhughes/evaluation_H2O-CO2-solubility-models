# %% [markdown]
# # Plotting for 'Evaluation of H2O-CO2 solubility models in silicate melts: Precision and accuracy of vapor saturation pressure and composition'
#
# Hughes & Saper (pre-print) Evaluation of H2O-CO2 solubility models in silicate melts: Precision and accuracy of vapor saturation pressure and composition. Earth ArXiv https://doi.org/10.31223/X57J50

# %% [markdown]
# ## Import relevant python packages and files

# %%
# import python packages
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import os

# %% [markdown]
# ## Import experimental data

# %%
input_data = pd.read_csv("all_experimental_data.csv")

# %% [markdown]
# ## Experiments in database
#
# ### TAS, PT, H2O-CO2

# %%
fig = make_subplots(rows=1, cols=3,
                   shared_yaxes = False, shared_xaxes = False,
                   vertical_spacing=0.03, horizontal_spacing=0.06)

data = input_data

# SiO2-Na2O+K2O
r = 1
c = 1
lwTAS = 1.
lcTAS = 'darkgrey'
fig.add_trace(go.Scatter(mode="lines", x=[41,41,41,45,48.5, 52.5,57.6,63,63], y = [0.5,3, 7, 9.4, 11.5, 14,11.7,7,0.5], 
                         showlegend=False,line_color = lcTAS,line_width=lwTAS))
fig.add_trace(go.Scatter(mode="lines", x=[45,45,49.4,53,57.6,61], y = [0.5,5,7.3,9.3,11.7,13.5], 
                         showlegend=False,line_color = lcTAS,line_width=lwTAS))
fig.add_trace(go.Scatter(mode="lines", x=[41,45,45,52,57,63,69,77.5], y = [3,3,5,5,5.9,7,8,0.5], 
                         showlegend=False,line_color = lcTAS,line_width=lwTAS))
fig.add_trace(go.Scatter(mode="lines", x=[69,69], y = [8,14], 
                         showlegend=False,line_color = lcTAS,line_width=lwTAS))
fig.add_trace(go.Scatter(mode="lines", x=[57,57,53,48.4,45,49.4,52,52], y = [0.5,5.9,9.3,11.5,9.4,7.3,5,0.5], 
                         showlegend=False,line_color = lcTAS,line_width=lwTAS))
fig.add_trace(go.Scatter(mode = "markers", x=data["SiO2_n"], y=data["TA_n"], showlegend=False,
                         #error_x=dict(type='data', array=2*data["T_C_sd"],visible=True,width=0,color='black'),
                         #error_y=dict(type='data', array=2*data["P_bar_sd"],visible=True,width=0,color='black'),
                         marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=8., line_width=1)), row = r, col = c)
fig.update_xaxes(range = [40,80], dtick = 5, title = "SiO<sub>2</sub> (wt% VFN)", row = r, col = c)
fig.update_yaxes(range = [0,16], dtick = 5, title = "Na<sub>2</sub>O+K<sub>2</sub>O (wt% VFN)",  row = r, col = c)
fig.add_annotation(x=77.5, y=15.,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# P-T
r = 1
c = 2
fig.add_trace(go.Scatter(mode = "markers", x=data["T_C"], y=data["P_bar"]/1000, showlegend=False,
                         #error_x=dict(type='data', array=data['T_C sd'],visible=True,width=0,color='grey'),
                         #error_y=dict(type='data', array=data["P_bar sd"]/1000.,visible=True,width=0,color='grey'),
                         marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=8., line_width=1)), row = r, col = c)
fig.update_xaxes(range = [750,1450], dtick = 200, title = "<i>T</i><sub>exp</sub> (\u00B0C)", row = r, col = c)
fig.update_yaxes(range = [13,0], dtick = 5, title = "<i>P</i><sub>exp</sub> (kbar)",  row = r, col = c)
fig.add_annotation(x=1410, y=0.8,text="b",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# CO2-H2O
r = 1
c = 3
fig.add_trace(go.Scatter(mode = "markers", x=data["H2O_wt%"], y=data["CO2_ppm"]/10000, showlegend=False,
                         #error_x=dict(type='data', array=data['H2O_wt% sd'],visible=True,width=0,color='grey'),
                         #error_y=dict(type='data', array=data["CO2_ppm sd"]/1000.,visible=True,width=0,color='grey'),
                         marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=8., line_width=1)), row = r, col = c)
fig.update_xaxes(range = [0,12], dtick = 2, title = "glass H<sub>2</sub>O (wt%)", row = r, col = c)
fig.update_yaxes(range = [0,2.2], dtick = 0.5, title = "glass CO<sub>2</sub> (wt%)", tickformat='.1f',  row = r, col = c)
fig.add_annotation(x=11.3, y=2.05,text="c",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

ss_leg = 6.
lw_leg = 1.
# legend
# basalt
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-left", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Juan de Fuca Ridge: Stolper+Holloway88,Dixon+95"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="x", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Juan de Fuca Ridge: Pawley+92,Dixon+95"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-down", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mid-Atlantic Ridge: Shishkina+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="star-triangle-down", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Stromboli: Iacono-Marziano+08"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="star-triangle-up", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Stromboli: Lesne+10,11CMP"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond-wide", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Stromboli: Allison+19"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Campi Flegrei: Fanara+15"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Masaya: Lesne+11JP"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-right", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mutnovsky: Shishkina+10"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="pentagon", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mecinka: Shishkina+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-up", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mecinka: Shishkina+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond-tall", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Paradise Falls: Blatter+13"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="star-square", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Sunset Crater: Allison+19"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="cross", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Kerguelen: Shishkina+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="star", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Skaergaard: Botcharnikov+05,Shishkina+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mars: Stanley+11"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="star-diamond", color='#0173b2', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mars: Stanley+12"))
# basaltic andesite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#de8f05', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Galapagos Spreading Center: Jendrzejewski+97"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-down", color='#de8f05', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Stromboli: Lesne+11JP"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-up", color='#de8f05', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Pavlof: Mangan+21"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="cross", color='#de8f05', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="San Francisco Volcanic Field: Allison+19"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="x", color='#de8f05', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="St Kitts: Melekhova+17"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#de8f05', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Hekla: Jakobsson+97"))
# andesite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond", color='#029e73', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Unzen: Botcharnikov+06,07"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#029e73', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mt Hood: King+Holloway02"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#029e73', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="St Kitts: Melekhova+17"))
# dacite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond", color='#d55e00', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Unzen: Behrens+04"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#d55e00', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mount St. Helens: Blatter+17"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#d55e00', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mount St. Helens: Riker+15"))
# rhyolite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#cc78bc', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Glass Buttes: Blank+93"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="cross", color='#cc78bc', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Valles Caldera: Fogel+Rutherford90"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond", color='#cc78bc', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Mount St. Helens: Riker+15"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-up", color='#cc78bc', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Panum Crater Dome: Mangan+Sisson00"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#cc78bc', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Erevan Dry Fountain: Tamic+01,Behrens+04"))
# trachybasalt
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond", color='#56b4e9', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Etna: Lesne+10,11CMP,Iacono-Marziano+12"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#56b4e9', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Etna: Shishkina+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-up", color='#56b4e9', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Etna: Hughes+18,TS"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#56b4e9', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Etna: Allison+19"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="cross", color='#56b4e9', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Etna: Shea+19"))
# trachybasaltic andesite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#949494', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Vulcano: Vetere+11,14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#949494', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Torre Alfina: Iacono-Marziano+21"))
# trachyandesite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#ca9161', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Lipari: Vetere+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#ca9161', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Torre Alfina: Iacono-Marziano+12"))
# trachyte
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='black', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Campi Flegrei: Fanara+15"))
# Basanite/Tephrite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#ece133', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Tenerife: Jiménez-Mejías+21"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-up", color='#ece133', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Torre Alfina: Iacono-Marziano+12"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#ece133', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Rutki-Ligota: Shishkina+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond", color='#ece133', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Gracze: Shishkina+14"))
# Phonotephrite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-down", color='#fbafe4', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Vesuvius: Lesne+10,11CMP"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="x", color='#fbafe4', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Vesuvius: Allison+19"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='#fbafe4', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Alban Hills: Behrens+09,Vetere+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='#fbafe4', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Alban Hills: Vetere+14"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-up", color='#fbafe4', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Erebus: Iacovino+13"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond", color='#fbafe4', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Erebus: Allison+19"))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="cross", color='#fbafe4', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Tenerife: Jiménez-Mejías+21"))
# Phonolite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='black', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Vesuvius: Schanofski+19"))
# Foidite
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="diamond", color='black', line_color="black", size=ss_leg, line_width=lw_leg),
                         name="Colli Albani: Schanofski+19"))

fig.update_legends(font_size=10)
                   
fig.update_layout(legend=dict(
    orientation="h",
    #entrywidth=70,
    yanchor="bottom",
    y=-1.7,
    xanchor="right",
    x=0.95
))

fig.update_layout(height=800, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = True)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# ### Oxide-silica plots

# %%
max_row = 3
max_col = 3

fig = make_subplots(rows=max_row, cols=max_row,
                   shared_yaxes = False, shared_xaxes = True,
                   vertical_spacing=0.02, horizontal_spacing=0.06)

data = input_data
data['total'] = data['SiO2_wt%']+data['Al2O3_wt%']+data['Na2O_wt%']+data['MgO_wt%']+data['CaO_wt%']+data['TiO2_wt%']+data['FeOT_wt%']+data['MnO_wt%']+data['K2O_wt%']+data['P2O5_wt%']
# SiO2-
r = 1
c = 0
for oxide2 in ['Al2O3','Na2O','MgO','CaO','TiO2','FeOT','MnO','K2O','P2O5']:
    oxide = oxide2+'_wt%'
    if c == max_col:
        c = 1
        r = r+1
    else:
        c=c+1
    fig.add_trace(go.Scatter(mode = "markers", x=(100*data["SiO2_wt%"])/data['total'], y=(100*data[oxide])/data['total'], showlegend=False,
                         #error_x=dict(type='data', array=2*data["T_C_sd"],visible=True,width=0,color='black'),
                         #error_y=dict(type='data', array=2*data["P_bar_sd"],visible=True,width=0,color='black'),
                         marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    if oxide2 == 'Al2O3':
        oxide2 = 'Al<sub>2</sub>O<sub>3</sub>'
    elif oxide2 == 'Na2O':
        oxide2 = 'Na<sub>2</sub>O'
    elif oxide2 == 'K2O':
        oxide2 = 'K<sub>2</sub>O'
    elif oxide2 == 'P2O5':
        oxide2 = 'P<sub>2</sub>O<sub>5</sub>'
    elif oxide2 == 'FeOT':
        oxide2 = 'FeO<sub>T</sub>'
    elif oxide2 == 'TiO2':
        oxide2 = 'TiO<sub>2</sub>'
    fig.update_yaxes(title = 'glass '+oxide2+' (wt% VFN)',  row = r, col = c)
    if oxide == 'P2O5_wt%':
        fig.update_yaxes(range=(0,1.5),row = r, col = c)
fig.update_xaxes(range = [40,80], dtick = 5, title = "glass SiO<sub>2</sub> (wt% VFN)", row = max_row)

fig.add_annotation(x=78, y=19.8,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = 1, col = 1)
fig.add_annotation(x=78, y=6.2,text="b",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = 1, col = 2)
fig.add_annotation(x=78, y=19.,text="c",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = 1, col = 3)
fig.add_annotation(x=78, y=13,text="d",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = 2, col = 1)
fig.add_annotation(x=78, y=3.8,text="e",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = 2, col = 2)
fig.add_annotation(x=78, y=19.2,text="f",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = 2, col = 3)
fig.add_annotation(x=78, y=0.455,text="g",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = 3, col = 1)
fig.add_annotation(x=78, y=9.5,text="h",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = 3, col = 2)
fig.add_annotation(x=78, y=1.43,text="i",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = 3, col = 3)

fig.update_layout(height=1000, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# ### H2O-XH2O, CO2-XCO2, and FeOT-Fe3+/FeT

# %%
fig = make_subplots(rows=1, cols=3,
                   shared_yaxes = False, shared_xaxes = False,
                   vertical_spacing=0.03, horizontal_spacing=0.06)

data = input_data

# H2O xH2O
r = 1
c = 1
fig.add_trace(go.Scatter(mode = "markers", x=data["H2O_wt%"], y=data["XH2Of"], showlegend=False,
                         #error_x=dict(type='data', array=2*data["T_C_sd"],visible=True,width=0,color='black'),
                         #error_y=dict(type='data', array=2*data["P_bar_sd"],visible=True,width=0,color='black'),
                         marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=8., line_width=1)), row = r, col = c)
fig.update_xaxes(range = [0,12], dtick = 2, title = "glass H<sub>2</sub>O (wt%)", row = r, col = c)
fig.update_yaxes(range = [-0.01,1.01], dtick = 0.2, tickformat='.1f', title = "vapor H<sub>2</sub>O (mole fraction)",  row = r, col = c)
fig.add_annotation(x=11.4, y=0.05,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# CO2 CO2
r = 1
c = 2
fig.add_trace(go.Scatter(mode = "markers", x=data["CO2_ppm"]/10000, y=data["XCO2f"], showlegend=False,
                         #error_x=dict(type='data', array=data['T_C sd'],visible=True,width=0,color='grey'),
                         #error_y=dict(type='data', array=data["P_bar sd"]/1000.,visible=True,width=0,color='grey'),
                         marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=8., line_width=1)), row = r, col = c)
fig.update_xaxes(range = [0,2.2], dtick = 0.5, tickformat='.1f', title = "glass CO<sub>2</sub> (wt%)", row = r, col = c)
fig.update_yaxes(range = [-0.01,1.01], dtick = 0.2, tickformat='.1f', title = "vapor CO<sub>2</sub> (mole fraction)",  row = r, col = c)
fig.add_annotation(x=2.05, y=0.95,text="b",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# FeO Fe3+/FeT
r = 1
c = 3
fig.add_trace(go.Scatter(mode = "markers", x=data['FeOT_wt%'], y=data['Fe3_FeT'], showlegend=False,
                         #error_x=dict(type='data', array=data['H2O_wt% sd'],visible=True,width=0,color='grey'),
                         #error_y=dict(type='data', array=data["CO2_ppm sd"]/1000.,visible=True,width=0,color='grey'),
                         marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=8., line_width=1)), row = r, col = c)
fig.update_xaxes(range = [4,14], dtick = 2, title = "glass FeO<sub>T</sub> (wt% VFN)", row = r, col = c)
fig.update_yaxes(range = [0,1], dtick = 0.2, title = "glass Fe<sup>3+</sup>/Fe<sub>T</sub>", tickformat='.1f',  row = r, col = c)
fig.add_annotation(x=13.5, y=0.95,text="c",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

fig.update_layout(height=400, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = True)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# ## Compare models

# %%
# import data
ShishkinaIdealMixing = pd.read_csv("results_pvsat_MC_VESIcal/results_pvsat_MC_VESIcal_ShishkinaIdealMixing.csv")
Dixon = pd.read_csv("results_pvsat_MC_VESIcal/results_pvsat_MC_VESIcal_Dixon.csv")
IaconoMarziano = pd.read_csv("results_pvsat_MC_VESIcal/results_pvsat_MC_VESIcal_IaconoMarziano.csv")
IaconoMarziano = IaconoMarziano[IaconoMarziano['P_bar sd model']<=1000.]
MagmaSat = pd.read_csv("results_pvsat_MC_VESIcal/results_pvsat_MC_VESIcal_MagmaSat.csv")
Liu = pd.read_csv("results_pvsat_MC_VESIcal/results_pvsat_MC_VESIcal_Liu.csv")

# %% [markdown]
# ### TAS, PT, H2O-CO2

# %%
max_row = 5
max_col = 3

fig = make_subplots(rows=max_row, cols=max_col,
                   shared_yaxes = False, shared_xaxes = True,
                   vertical_spacing=0.02, horizontal_spacing=0.06)#,
                   #subplot_titles=('VESIcal-Dixon','VESIcal-ShishkinaIdealMixing','VESIcal-IaconoMarziano','VESIcal-Liu','VESIcal-MagmaSat'))

#fig.update_annotations(yshift=10)

r=0
for model in ['Dixon','IaconoMarziano','ShishkinaIdealMixing','Liu','MagmaSat']:
    
    dataset = eval(model)
    r = r+1
    
    # TAS
    c = 1
    lwTAS = 1.
    lcTAS = 'darkgrey'
    fig.add_trace(go.Scatter(mode="lines", x=[41,41,41,45,48.5, 52.5,57.6,63,63], y = [0.5,3, 7, 9.4, 11.5, 14,11.7,7,0.5], 
                            showlegend=False,line_color = lcTAS,line_width=lwTAS), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[45,45,49.4,53,57.6,61], y = [0.5,5,7.3,9.3,11.7,13.5], 
                            showlegend=False,line_color = lcTAS,line_width=lwTAS), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[41,45,45,52,57,63,69,77.5], y = [3,3,5,5,5.9,7,8,0.5], 
                            showlegend=False,line_color = lcTAS,line_width=lwTAS), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[69,69], y = [8,14], 
                            showlegend=False,line_color = lcTAS,line_width=lwTAS), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[57,57,53,48.4,45,49.4,52,52], y = [0.5,5.9,9.3,11.5,9.4,7.3,5,0.5], 
                            showlegend=False,line_color = lcTAS,line_width=lwTAS), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data["SiO2_n"], y=data["TA_n"], showlegend=False,
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data["SiO2_n"], y=data["TA_n"], showlegend=False,
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_xaxes(range = [40,80], dtick = 5, row = r, col = c)
    fig.update_xaxes(title = "SiO<sub>2</sub> (wt% VFN)", row = 5, col = c)
    fig.update_yaxes(range = [0,16], dtick = 5, title = "Na<sub>2</sub>O+K<sub>2</sub>O (wt% VFN)", row = r, col = c)
    
    # PT
    c = 2
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data["T_C"], y=data["P_bar"]/1000., showlegend=False,
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data["T_C"], y=data["P_bar"]/1000., showlegend=False,
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_xaxes(range = [750, 1450], dtick = 200, row = r, col = c)
    fig.update_xaxes(title = "<i>T</i><sub>exp</sub> (\u00B0C)", row = 5, col = c)
    fig.update_yaxes(range = [13,0], dtick = 5, title = "<i>P</i><sub>exp</sub> (kbar)", row = r, col = c)

    # CO2-H2O

    c = 3
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data["H2O_wt%"], y=data["CO2_ppm"]/10000., showlegend=False,
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data["H2O_wt%"], y=data["CO2_ppm"]/10000., showlegend=False,
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_xaxes(range = [0, 12], dtick = 2, row = r, col = c)
    fig.update_xaxes(title = "glass H<sub>2</sub>O (wt%)", row = 5, col = c)
    fig.update_yaxes(range = [0,2.2], dtick = 0.5, title = "glass CO<sub>2</sub> (wt%)", tickformat='.1f', row = r, col = c)

    fig.add_annotation(x=12., y=1.1, ax=11, ay=0,text=model,showarrow=True, arrowcolor='white',
                   font=dict(color="black",size=15),textangle=90,  row = r, col = 3)

r=0    
for x in ['a','d','g','j','m']:
    r=r+1
    fig.add_annotation(x=78, y=15,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 1)
r=0    
for x in ['b','e','h','k','n']:
    r=r+1
    fig.add_annotation(x=1410, y=1,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 2)
r=0    
for x in ['c','f','i','l','o']:
    r=r+1
    fig.add_annotation(x=11.4, y=2.05,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 3)

fig.update_layout(height=1200, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# ### Calculated Pressure

# %%
max_row = 5
max_col = 4

fig = make_subplots(rows=max_row, cols=max_col,
                   shared_yaxes = False, shared_xaxes = True,
                   vertical_spacing=0.02, horizontal_spacing=0.06)#,
                   #subplot_titles=('VESIcal-Dixon','VESIcal-ShishkinaIdealMixing','VESIcal-IaconoMarziano','VESIcal-Liu','VESIcal-MagmaSat'))

#fig.update_annotations(yshift=10)



r=0
for model in ['Dixon','IaconoMarziano','ShishkinaIdealMixing','Liu','MagmaSat',]:
    dataset = eval(model)
    r = r+1

    #Pexp-Pcalc
    c = 1
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_yaxes(range = [0,20], dtick = 5, title = '<i>P</i><sub>calc</sub> (kbar)', row = r, col = c)
    fig.update_xaxes(range = [0,20], dtick = 5, row = r, col = c)
    fig.update_xaxes(title = '<i>P</i><sub>exp</sub> (kbar)', row = 5, col = c)

    # Pexp-Pdiff
    c = 2
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,0], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0.2,0.2], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [-0.2,-0.2], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=((data['P_bar model']-data['P_bar'])/data['P_bar']), showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=((((((data["P_bar sd"]**2.+data["P_bar sd model"]**2.)**0.5)/(data['P_bar model']-data['P_bar']))**2.+(data["P_bar sd"]/data['P_bar'])**2.)**0.5)*((data['P_bar model']-data['P_bar'])/data['P_bar'])),visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=((data['P_bar model']-data['P_bar'])/data['P_bar']), showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=((((((data["P_bar sd"]**2.+data["P_bar sd model"]**2.)**0.5)/(data['P_bar model']-data['P_bar']))**2.+(data["P_bar sd"]/data['P_bar'])**2.)**0.5)*((data['P_bar model']-data['P_bar'])/data['P_bar'])),visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_yaxes(range = [-2,2], dtick = 1, title = 'normalised error',  row = r, col = c)
    fig.update_xaxes(range = [0,20], dtick = 5, row = r, col = c)
    fig.update_xaxes(title = '<i>P</i><sub>exp</sub> (kbar)', row = 5, col = c)
    
    # histogram
    c=3
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity=0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=5, col=c)
    fig.update_yaxes(range=(0,0.66), title='proportion of data', tickformat='.1f', row=r, col=c)

    # uncertainty
    c = 4
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                                showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                                showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar sd'], y=data['P_bar sd model'], showlegend=False,
                                marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar sd'], y=data['P_bar sd model'], showlegend=False,
                                marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_yaxes(range = [0,1400], dtick = 200, title = '<i>P</i><sub>calc</sub> uncertainty (bar)', row = r, col = c)
    fig.update_xaxes(range = [0,300], dtick = 50, row = r, col = c)
    fig.update_xaxes(title = '<i>P</i><sub>exp</sub> uncertainty (bar)', row = 5, col = c)
    
    fig.add_annotation(x=300, y=650, ax=11, ay=0,text=model,showarrow=True, arrowcolor='white',
                   font=dict(color="black",size=15),textangle=90,  row = r, col = 4)
    
r=0    
for x in ['a','e','i','m','q']:
    r=r+1
    fig.add_annotation(x=20*0.08, y=20*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 1)
r=0    
for x in ['b','f','j','n','r']:
    r=r+1
    fig.add_annotation(x=20*0.92, y=(4*0.92)-2,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 2)
r=0    
for x in ['c','g','k','o','s']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.66*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 3)
r=0  
for x in ['d','h','l','p','t']:
    r=r+1
    fig.add_annotation(x=300*0.92, y=1400*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 4)
    
fig.update_layout(height=1200, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# ### Calculated xvH2O

# %%
max_row = 5
max_col = 4

fig = make_subplots(rows=max_row, cols=max_col,
                   shared_yaxes = False, shared_xaxes = True,
                   vertical_spacing=0.02, horizontal_spacing=0.06)

r=0
for model in ['Dixon','IaconoMarziano','ShishkinaIdealMixing','Liu','MagmaSat',]:
    dataset = eval(model)
    r = r+1
    #xH2O
    c = 1
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=3.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=3.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', title = 'calculated <i>x<sup>v</sup></i><sub>H<sub>2</sub>O<sub>', row = r, col = c)
    fig.update_xaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>v</sup></i><sub>H<sub>2</sub>O<sub>', row = 5, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

    # difference
    c = 2
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=((data['xgH2O model']-data['XH2Of'])/data['XH2Of']), showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=((((((data["XH2Of sd"]**2.+data["xgH2O sd model"]**2.)**0.5)/(data['xgH2O model']-data['XH2Of']))**2.+(data["XH2Of sd"]/data['XH2Of'])**2.)**0.5)*((data['xgH2O model']-data['XH2Of'])/data['XH2Of'])),visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=((data['xgH2O model']-data['XH2Of'])/data['XH2Of']), showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=((((((data["XH2Of sd"]**2.+data["xgH2O sd model"]**2.)**0.5)/(data['xgH2O model']-data['XH2Of']))**2.+(data["XH2Of sd"]/data['XH2Of'])**2.)**0.5)*((data['xgH2O model']-data['XH2Of'])/data['XH2Of'])),visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,0], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0.2,0.2], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [-0.2,-0.2], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [-2,2], dtick = 1, title = 'normalised error',  row = r, col = c)
    fig.update_xaxes(range = [0.1,1.1], dtick = 0.2, tickformat='.1f', row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>v</sup></i><sub>H<sub>2</sub>O<sub>', row = 5, col = c)

    #histogram
    c=3
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity = 0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=5, col=c)
    fig.update_yaxes(range=(0,0.5), title='proportion of data', tickformat='.1f', row=r, col=c)

    # uncertainty
    c = 4
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of sd'], y=data['xgH2O sd model'], showlegend=False,
                                marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of sd'], y=data['xgH2O sd model'], showlegend=False,
                                marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,2], y = [0,2], 
                                showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[2,0,2], y = [2.4,0,1.6], 
                                showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [0,0.15], dtick = 0.05, tickformat='.2f', title = 'calculated <i>x<sup>v</sup></i><sub>H<sub>2</sub>O<sub>', row = r, col = c)
    fig.update_xaxes(range = [0,0.9], dtick = 0.2, tickformat='.1f', row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>v</sup></i><sub>H<sub>2</sub>O<sub>', row = 5, col = c)

    fig.add_annotation(x=0.9, y=0.075, ax=11, ay=0,text=model,showarrow=True, arrowcolor='white',
                   font=dict(color="black",size=15),textangle=90,  row = r, col = 4)

r=0    
for x in ['a','e','i','m','q']:
    r=r+1
    fig.add_annotation(x=0.02, y=0.98,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 1)
r=0    
for x in ['b','f','j','n','r']:
    r=r+1
    fig.add_annotation(x=1., y=(4*0.92)-2,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 2)
r=0    
for x in ['c','g','k','o','s']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.5*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 3)
r=0   
for x in ['d','h','l','p','t']:
    r=r+1
    fig.add_annotation(x=0.83, y=0.15*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 4)
    
fig.update_layout(height=1200, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# ### Calculated xvCO2

# %%
max_row = 5
max_col = 4

fig = make_subplots(rows=max_row, cols=max_col,
                   shared_yaxes = False, shared_xaxes = True,
                   vertical_spacing=0.02, horizontal_spacing=0.06)

r=0
for model in ['Dixon','IaconoMarziano','ShishkinaIdealMixing','Liu','MagmaSat']:
    dataset = eval(model)
    r = r+1
    #xH2O
    c = 1
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XCO2f'], y=data['xgCO2 model'], showlegend=False,
                            error_x=dict(type='data', array=data['XCO2f sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgCO2 sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XCO2f'], y=data['xgCO2 model'], showlegend=False,
                            error_x=dict(type='data', array=data['XCO2f sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgCO2 sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=3.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=3.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', title = 'calculated <i>x<sup>v</sup></i><sub>CO<sub>2</sub><sub>', row = r, col = c)
    fig.update_xaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>v</sup></i><sub>CO<sub>2</sub><sub>', row = 5, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

    # difference
    c = 2
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XCO2f'], y=((data['xgCO2 model']-data['XCO2f'])/data['XCO2f']), showlegend=False,
                            error_x=dict(type='data', array=data['XCO2f sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=((((((data["XCO2f sd"]**2.+data["xgCO2 sd model"]**2.)**0.5)/(data['xgCO2 model']-data['XH2Of']))**2.+(data["XCO2f sd"]/data['XCO2f'])**2.)**0.5)*((data['xgCO2 model']-data['XCO2f'])/data['XCO2f'])),visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XCO2f'], y=((data['xgCO2 model']-data['XCO2f'])/data['XCO2f']), showlegend=False,
                            error_x=dict(type='data', array=data['XCO2f sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=((((((data["XCO2f sd"]**2.+data["xgCO2 sd model"]**2.)**0.5)/(data['xgCO2 model']-data['XCO2f']))**2.+(data["XCO2f sd"]/data['XCO2f'])**2.)**0.5)*((data['xgCO2 model']-data['XCO2f'])/data['XCO2f'])),visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,0], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0.2,0.2], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [-0.2,-0.2], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [-2,2], dtick = 1, title = 'normalised error',  row = r, col = c)
    fig.update_xaxes(range = [0.1,1.1], tickformat='.1f', dtick = 0.2, row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>v</sup></i><sub>CO<sub>2</sub><sub>', row = 5, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
    #histogram
    c=3
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = (data['xgCO2 model']-data['XCO2f'])/data['XCO2f']
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey',  marker_opacity = 0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = (data['xgCO2 model']-data['XCO2f'])/data['XCO2f']
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=5, col=c)
    fig.update_yaxes(range=(0,0.72), title='proportion of data', row=r, col=c)

    # uncertainty
    c = 4
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XCO2f sd'], y=data['xgCO2 sd model'], showlegend=False,
                                marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XCO2f sd'], y=data['xgCO2 sd model'], showlegend=False,
                                marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,2], y = [0,2], 
                                showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[2,0,2], y = [2.4,0,1.6], 
                                showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [0,0.15], dtick = 0.05, tickformat='.2f', title = 'calculated <i>x<sup>v</sup></i><sub>CO<sub>2</sub><sub>', row = r, col = c)
    fig.update_xaxes(range = [0,0.7], dtick = 0.2, tickformat='.1f', row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>v</sup></i><sub>CO<sub>2</sub><sub>', row = 5, col = c)

    fig.add_annotation(x=0.7, y=0.075, ax=11, ay=0,text=model,showarrow=True, arrowcolor='white',
               font=dict(color="black",size=15),textangle=90,  row = r, col = 4)
        
r=0    
for x in ['a','e','i','m','q']:
    r=r+1
    fig.add_annotation(x=0.98, y=0.02,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 1)
r=0    
for x in ['b','f','j','n','r']:
    r=r+1
    fig.add_annotation(x=1., y=(4*0.92)-2,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 2)
r=0    
for x in ['c','f','j','n','r']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.72*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 3)
r=0  
for x in ['d','h','l','p','t']:
    r=r+1
    fig.add_annotation(x=0.65, y=0.15*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 4)

fig.update_layout(height=1200, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# ### For different compositions
#
# #### Intermediate

# %%
max_row = 5
max_col = 4

fig = make_subplots(rows=max_row, cols=max_col,
                   shared_yaxes = False, shared_xaxes = False,
                   vertical_spacing=0.02, horizontal_spacing=0.06)#,
                   #subplot_titles=('VESIcal-Dixon','VESIcal-ShishkinaIdealMixing','VESIcal-IaconoMarziano','VESIcal-Liu','VESIcal-MagmaSat'))

#fig.update_annotations(yshift=10)



r=0
for model in ['IaconoMarziano','ShishkinaIdealMixing','MagmaSat']:
    dataset = eval(model)
    dataset = dataset[(dataset['Composition']=='Andesite') | (dataset['Composition']=='Dacite')]
    r = r+1

    #Pexp-Pcalc
    c = 1
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_yaxes(range = [0,17], dtick = 5, title = '<i>P</i><sub>calc</sub> (kbar)', row = r, col = c)
    fig.update_xaxes(range = [0,11], dtick = 5, row = r, col = c)
    fig.update_xaxes(title = '<i>P</i><sub>exp</sub> (kbar)', row = 3, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
    
    # histogram
    c=2
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity=0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=3, col=c)
    fig.update_yaxes(range=(0,0.4), title='proportion of data', tickformat='.1f', row=r, col=c)

    #xH2O
    c = 3
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=3.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=3.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', title = 'calculated <i>x<sup>g</sup></i><sub>H<sub>2</sub>O<sub>', row = r, col = c)
    fig.update_xaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>g</sup></i><sub>H<sub>2</sub>O<sub>', row = 3, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

    #histogram
    c=4
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity = 0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=3, col=c)
    fig.update_yaxes(range=(0,0.9), title='proportion of data', tickformat='.1f', row=r, col=c)

    fig.add_annotation(x=2, y=0.45, ax=11, ay=0,text=model,showarrow=True, arrowcolor='white',
               font=dict(color="black",size=15),textangle=90,  row = r, col = 4)

r=0    
for x in ['a','e','i']:
    r=r+1
    fig.add_annotation(x=0.92*11, y=0.92*17,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 1)
r=0    
for x in ['b','f','j']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.92*0.4,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 2)
r=0    
for x in ['c','g','k']:
    r=r+1
    fig.add_annotation(x=0.02, y=0.98,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 3)
r=0    
for x in ['d','h','l']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.9*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 4)
    
fig.update_layout(height=1200, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# #### rhyolite

# %%
max_row = 5
max_col = 4

fig = make_subplots(rows=max_row, cols=max_col,
                   shared_yaxes = False, shared_xaxes = False,
                   vertical_spacing=0.02, horizontal_spacing=0.06)#,

r=0
for model in ['Liu','MagmaSat']:
    dataset = eval(model)
    dataset = dataset[(dataset['Composition']=='Rhyolite')]
    r = r+1

    #Pexp-Pcalc
    c = 1
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_yaxes(range = [0,9], dtick = 2, title = '<i>P</i><sub>calc</sub> (kbar)', row = r, col = c)
    fig.update_xaxes(range = [0,9], dtick = 2, row = r, col = c)
    fig.update_xaxes(title = '<i>P</i><sub>exp</sub> (kbar)', row = 2, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
    
    # histogram
    c=2
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity=0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=2, col=c)
    fig.update_yaxes(range=(0,0.7), title='proportion of data', tickformat='.1f', row=r, col=c)

    #xH2O
    c = 3
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=3.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=3.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', title = 'calculated <i>x<sup>g</sup></i><sub>H<sub>2</sub>O<sub>', row = r, col = c)
    fig.update_xaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>g</sup></i><sub>H<sub>2</sub>O<sub>', row = 2, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

    #histogram
    c=4
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity = 0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=2, col=c)
    fig.update_yaxes(range=(0,0.6), title='proportion of data', tickformat='.1f', row=r, col=c)

    fig.add_annotation(x=2, y=0.3, ax=11, ay=0,text=model,showarrow=True, arrowcolor='white',
               font=dict(color="black",size=15),textangle=90,  row = r, col = 4)
    
r=0    
for x in ['a','e']:
    r=r+1
    fig.add_annotation(x=0.92*9, y=0.92*9,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 1)
r=0    
for x in ['b','f']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.92*0.7,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 2)
r=0    
for x in ['c','g']:
    r=r+1
    fig.add_annotation(x=0.02, y=0.98,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 3)
r=0    
for x in ['d','h']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.6*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 4)
    
fig.update_layout(height=1200, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# #### Basalt to basaltic andesite

# %%
max_row = 5
max_col = 4

fig = make_subplots(rows=max_row, cols=max_col,
                   shared_yaxes = False, shared_xaxes = False,
                   vertical_spacing=0.02, horizontal_spacing=0.06)#,

r=0
for model in ['Dixon','IaconoMarziano','ShishkinaIdealMixing','MagmaSat']:
    dataset = eval(model)
    dataset = dataset[(dataset['Composition']=='Basalt') | (dataset['Composition']=='Basaltic-andesite')]
    r = r+1

    #Pexp-Pcalc
    c = 1
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_yaxes(range = [0,20], dtick = 5, title = '<i>P</i><sub>calc</sub> (kbar)', row = r, col = c)
    fig.update_xaxes(range = [0,20], dtick = 5, row = r, col = c)
    fig.update_xaxes(title = '<i>P</i><sub>exp</sub> (kbar)', row = 4, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
    
    # histogram
    c=2
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity=0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=4, col=c)
    fig.update_yaxes(range=(0,0.6), title='proportion of data', tickformat='.1f', row=r, col=c)

    #xH2O
    c = 3
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=3.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=3.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', title = 'calculated <i>x<sup>g</sup></i><sub>H<sub>2</sub>O<sub>', row = r, col = c)
    fig.update_xaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>g</sup></i><sub>H<sub>2</sub>O<sub>', row = 4, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

    #histogram
    c=4
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity = 0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=4, col=c)
    fig.update_yaxes(range=(0,0.6), title='proportion of data', tickformat='.1f', row=r, col=c)
    
    fig.add_annotation(x=2, y=0.3, ax=11, ay=0,text=model,showarrow=True, arrowcolor='white',
               font=dict(color="black",size=15),textangle=90,  row = r, col = 4)

r=0    
for x in ['a','e','i','m']:
    r=r+1
    fig.add_annotation(x=0.92*20, y=0.92*20,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 1)
r=0    
for x in ['b','f','j','n']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.92*0.6,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 2)
r=0    
for x in ['c','g','k','o']:
    r=r+1
    fig.add_annotation(x=0.02, y=0.98,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 3)
r=0    
for x in ['d','h','l','p']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.6*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 4)
    
fig.update_layout(height=1200, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# #### Alkali-rich

# %%
max_row = 5
max_col = 4

fig = make_subplots(rows=max_row, cols=max_col,
                   shared_yaxes = False, shared_xaxes = False,
                   vertical_spacing=0.02, horizontal_spacing=0.06)#,
                   #subplot_titles=('VESIcal-Dixon','VESIcal-ShishkinaIdealMixing','VESIcal-IaconoMarziano','VESIcal-Liu','VESIcal-MagmaSat'))

#fig.update_annotations(yshift=10)



r=0
for model in ['Dixon','IaconoMarziano','ShishkinaIdealMixing','MagmaSat']:
    dataset = eval(model)
    dataset = dataset[(dataset['Composition']=='Basanite') | (dataset['Composition']=='Foidite')| (dataset['Composition']=='Phonolite')| (dataset['Composition']=='Phonotephrite')| (dataset['Composition']=='Tephrite')| (dataset['Composition']=='Trachyandesite')| (dataset['Composition']=='Trachybasalt')| (dataset['Composition']=='Trachyte')]
    r = r+1

    #Pexp-Pcalc
    c = 1
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['P_bar']/1000., y=data['P_bar model']/1000., showlegend=False,
                            error_x=dict(type='data', array=data['P_bar sd']/1000.,visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["P_bar sd model"]/1000.,visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.update_yaxes(range = [0,18], dtick = 5, title = '<i>P</i><sub>calc</sub> (kbar)', row = r, col = c)
    fig.update_xaxes(range = [0,8], dtick = 2, row = r, col = c)
    fig.update_xaxes(title = '<i>P</i><sub>exp</sub> (kbar)', row = 4, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
    
    # histogram
    c=2
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity=0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = ((data['P_bar model']-data['P_bar'])/data['P_bar'])
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=4, col=c)
    fig.update_yaxes(range=(0,0.7), title='proportion of data', tickformat='.1f', row=r, col=c)

    #xH2O
    c = 3
    data = dataset[dataset['calib_'+model]=='Y']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color='white', line_color=data['Colour'], size=6., line_width=1)), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    fig.add_trace(go.Scatter(mode = "markers", x=data['XH2Of'], y=data['xgH2O model'], showlegend=False,
                            error_x=dict(type='data', array=data['XH2Of sd'],visible=True,width=0,color='grey'),
                            error_y=dict(type='data', array=data["xgH2O sd model"],visible=True,width=0,color='grey'),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color="black", size=6., line_width=1)), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0,10000], y = [0,10000], 
                            showlegend=False,line_color = 'black',line_width=3.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[10000,0,10000], y = [8000,0,12000], 
                            showlegend=False,line_color = 'black',line_width=3.,line_dash='dash'), row = r, col = c)
    fig.update_yaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', title = 'calculated <i>x<sup>g</sup></i><sub>H<sub>2</sub>O<sub>', row = r, col = c)
    fig.update_xaxes(range = [-0.1,1.1], dtick = 0.2, tickformat='.1f', row = r, col = c)
    fig.update_xaxes(title = 'reported <i>x<sup>g</sup></i><sub>H<sub>2</sub>O<sub>', row = 4, col = c)
    fig.add_annotation(x=500, y=1800,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

    #histogram
    c=4
    fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[0.2,0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    fig.add_trace(go.Scatter(mode="lines", x=[-0.2,-0.2], y = [0,1], 
                            showlegend=False,line_color = 'black',line_width=2.,line_dash='dash'), row = r, col = c)
    data = dataset[dataset['calib_'+model]=='N']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace2 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='grey', marker_opacity = 0.75, marker_line_color='black', marker_line_width=1.)
    data = dataset[dataset['calib_'+model]=='Y']
    hist = (data['xgH2O model']-data['XH2Of'])/data['XH2Of']
    trace1 = go.Histogram(x=hist, histnorm = 'probability', xbins=dict(start=-2, end=2, size=0.2), marker_color='white', marker_line_color='black', marker_line_width=2.)
    fig.add_trace(trace1, r,c)
    fig.add_trace(trace2, r,c)
    fig.update_layout(barmode='overlay')
    fig.update_xaxes(range=(-2,2), row=r, col=c)
    fig.update_xaxes(title = 'normalised error', row=4, col=c)
    fig.update_yaxes(range=(0,0.5), title='proportion of data', tickformat='.1f', row=r, col=c)

    fig.add_annotation(x=2, y=0.25, ax=11, ay=0,text=model,showarrow=True, arrowcolor='white',
               font=dict(color="black",size=15),textangle=90,  row = r, col = 4)

r=0    
for x in ['a','e','i','m']:
    r=r+1
    fig.add_annotation(x=0.92*8, y=0.92*18,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 1)
r=0    
for x in ['b','f','j','n']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.92*0.7,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 2)
r=0    
for x in ['c','g','k','o']:
    r=r+1
    fig.add_annotation(x=0.02, y=0.98,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 3)
r=0    
for x in ['d','h','l','p']:
    r=r+1
    fig.add_annotation(x=(4*0.92)-2, y=0.5*0.92,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = 4)
    
fig.update_layout(height=1200, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()

# %% [markdown]
# ### accuracy and precision

# %%
acc_pre = pd.read_csv("accuracy_precision.csv")

# %%
max_row = 2
max_col = 2

fig = make_subplots(rows=max_row, cols=max_col,
                   shared_yaxes = True, shared_xaxes = True,
                   vertical_spacing=0.03, horizontal_spacing=0.02)#,
                   #subplot_titles=('VESIcal-Dixon','VESIcal-ShishkinaIdealMixing','VESIcal-IaconoMarziano','VESIcal-Liu','VESIcal-MagmaSat'))

for r in [1,2]:
    for c in [1,2]:
        fig.add_trace(go.Scatter(mode="lines", x=[-200,300], y = [0,0], 
                                    showlegend=False,line_color = 'lightgrey',line_width=7.), row = r, col = c)
        fig.add_trace(go.Scatter(mode="lines", x=[0,0], y = [-200,200], 
                                    showlegend=False,line_color = 'lightgrey',line_width=7.), row = r, col = c)
        fig.add_trace(go.Scatter(mode="lines", x=[-200,300], y = [20,20], 
                                    showlegend=False,line_color = 'lightgrey',line_width=3., line_dash='dash'), row = r, col = c)
        fig.add_trace(go.Scatter(mode="lines", x=[20,20], y = [-200,200], 
                                    showlegend=False,line_color = 'lightgrey',line_width=3., line_dash='dash'), row = r, col = c)
        fig.add_trace(go.Scatter(mode="lines", x=[-200,300], y = [-20,-20], 
                                    showlegend=False,line_color = 'lightgrey',line_width=3., line_dash='dash'), row = r, col = c)
        fig.add_trace(go.Scatter(mode="lines", x=[-20,-20], y = [-200,200], 
                                    showlegend=False,line_color = 'lightgrey',line_width=3., line_dash='dash'), row = r, col = c)

for comp in ['BBA','AR','I','R','all']:
    data = acc_pre[(acc_pre['Composition']==comp)]
    if comp == 'BBA':
        colour = '#0173b2'
        r,c=1,2
    elif comp == 'AR':
        colour = '#ece133'
        r,c=2,1
    elif comp == 'I':
        colour = '#029e73'
        r,c=2,2
    elif comp == 'R':
        colour = '#cc78bc'
        r,c=2,2
    if comp == 'all':
        r,c=1,1
        colour = 'black'
    fig.add_trace(go.Scatter(mode = "markers", x=data['pvsat acc. (%)'], y=data['xH2O acc. (mol.%)'], showlegend=False,
                            error_x=dict(type='data', array=data['pvsat pre. (%)'],visible=True,width=3,color=colour),
                            error_y=dict(type='data', array=data['xH2O pre. (mol.%)'],visible=True,width=3,color=colour),
                            marker=dict(symbol=data["Symbol"], color=data['Colour'], line_color='black', size=10., line_width=1)), row = r, col = c)

fig.update_yaxes(range=(-40,30)) 
fig.update_xaxes(range=(-110,220))
fig.update_yaxes(title='<i>x<sup>v</sup></i><sub>H<sub>2</sub>O</sub> accuracy (mol.%)', col = 1) 
fig.update_xaxes(title='<i>P<sup>v</sup></i><sub>sat</sub> accuracy (%)', row=2)   

for x in ['a','b','c','d']:
    if x == 'a':
        r,c=1,1
        y = 'All'
    elif x == 'b':
        r,c = 1,2
        y = 'Basalt-basaltic andesite'
    elif x == 'c':
        r,c = 2,1
        y = 'Alkali-rich'
    elif x == 'd':
        r,c = 2,2
        y = 'Intermediate/rhyolite'
    fig.add_annotation(x=205, y=25,text=x,showarrow=False, bordercolor = "black", bgcolor="white",
                    width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
    fig.add_annotation(x=50, y=25,text=y,showarrow=False,bgcolor="white",font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# Models
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="circle", color='grey', line_color="black", size=10., line_width=1.),
                         name="Dixon",legendgroup='Model'))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="triangle-up", color='grey', line_color="black", size=10., line_width=1.),
                         name="IacanoMarziano",legendgroup='Model'))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="square", color='grey', line_color="black", size=10., line_width=1.),
                         name="ShishkinaIdealMixing",legendgroup='Model'))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="x", color='grey', line_color="black", size=10., line_width=1.),
                         name="Liu",legendgroup='Model'))
fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
                         marker=dict(symbol="star", color='grey', line_color="black", size=10., line_width=1.),
                         name="MagmaSat",legendgroup='Model'))
#fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
#                         marker=dict(symbol="circle", color='white', line_color="black", size=15., line_width=2.),
#                         name="All",legendgroup='Composition'))
#fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
#                         marker=dict(symbol="circle", color='#0173b2', line_color="black", size=10., line_width=1.),
#                         name="Basaltic-basaltic and.",legendgroup='Composition'))
#fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
#                         marker=dict(symbol="circle", color='#ece133', line_color="black", size=10., line_width=1.),
#                         name="Alkali-rich",legendgroup='Composition'))
#fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
#                         marker=dict(symbol="circle", color= '#029e73', line_color="black", size=10., line_width=1.),
#                         name="Intermediate",legendgroup='Composition'))
#fig.add_trace(go.Scatter(mode = "markers", x=[-1000,-1000], y=[-1000,-1000],
#                         marker=dict(symbol="circle", color= '#cc78bc', line_color="black", size=10., line_width=1.),
#                         name="Rhyolite",legendgroup='Composition'))

fig.update_legends(font_size=10)
                   
fig.update_layout(legend=dict(
    orientation="h",
    #entrywidth=70,
    yanchor="top",
    y=0.75,
    xanchor="right",
    x=0.48
))

fig.update_layout(height=700, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = True)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()
